# %%
import duckdb

# %%
db_path = r'E:\git_repos\stock_analysis\data\raw_stock_price\stock_bar_data.db'
conn = duckdb.connect(db_path)

# %%
conn.execute("SELECT * FROM information_schema.tables").df()
# Out:
#     table_catalog table_schema     table_name  table_type  \
# 0  stock_bar_data         main     NVDA_day_1  BASE TABLE
# 1  stock_bar_data         main  NVDA_minute_1  BASE TABLE
# 2  stock_bar_data         main    NVDA_hour_1  BASE TABLE
#
#    self_referencing_column_name  reference_generation  \
# 0                           NaN                   NaN
# 1                           NaN                   NaN
# 2                           NaN                   NaN
#
#    user_defined_type_catalog  user_defined_type_schema  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
#
#    user_defined_type_name is_insertable_into is_typed commit_action
# 0                     NaN                YES       NO          None
# 1                     NaN                YES       NO          None
# 2                     NaN                YES       NO          None

# %%
conn.execute("SELECT * FROM NVDA_hour_1").df()
# Out:
#      symbol                 timestamp    open     high       low     close  \
# 0      NVDA 2023-07-17 03:00:00-05:00  458.22  459.300  456.5200  456.5300
# 1      NVDA 2023-07-17 04:00:00-05:00  456.71  457.420  456.1200  456.2800
# 2      NVDA 2023-07-17 05:00:00-05:00  456.38  458.100  456.2000  457.5200
# 3      NVDA 2023-07-17 06:00:00-05:00  457.43  457.930  455.7200  456.3300
# 4      NVDA 2023-07-17 07:00:00-05:00  457.72  460.410  452.2300  458.9000
# ...     ...                       ...     ...      ...       ...       ...
# 1985   NVDA 2024-01-11 07:00:00-06:00  549.80  551.650  546.1300  546.6400
# 1986   NVDA 2024-01-11 08:00:00-06:00  546.76  553.460  545.0100  548.5200
# 1987   NVDA 2024-01-11 09:00:00-06:00  548.55  548.651  538.8200  542.0647
# 1988   NVDA 2024-01-11 10:00:00-06:00  542.20  542.790  535.6000  538.9758
# 1989   NVDA 2024-01-11 11:00:00-06:00  538.87  547.120  538.7401  546.2510
#
#           volume  trade_count        vwap
# 0        39325.0       1371.0  458.263417
# 1        18296.0        734.0  456.758765
# 2        53748.0        996.0  457.691167
# 3       154417.0       3658.0  456.617583
# 4       334511.0       8636.0  457.547436
# ...          ...          ...         ...
# 1985   1189173.0      27111.0  549.295569
# 1986   9327515.0     142379.0  549.264203
# 1987  10299792.0     176964.0  543.129283
# 1988   8250085.0     105108.0  538.748357
# 1989   6447674.0      79043.0  543.307882
#
# [1990 rows x 9 columns]

# %%
conn.close()

# %%
import pandas_market_calendars as mcal
import datetime

# %%
nyse_calendar = mcal.get_calendar('NYSE')

# %%
datetime.datetime(2023, 11, 24, 16, 13, 7, 38930) in nyse_calendar.holidays().holidays
# Out:
# False
