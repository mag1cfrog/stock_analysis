# %%
import duckdb

# %%
db_path = r'E:\git_repos\stock_analysis\data\raw_stock_price\stock_bar_data.db'
conn = duckdb.connect(db_path)

# %%
conn.execute("SELECT * FROM information_schema.tables").df()
# Out:
#     table_catalog table_schema      table_name  table_type  \
# 0  stock_bar_data         main      NVDA_day_1  BASE TABLE
# 1  stock_bar_data         main   NVDA_minute_1  BASE TABLE
# 2  stock_bar_data         main     NVDA_hour_1  BASE TABLE
# 3  stock_bar_data         main  NVDA_minute_30  BASE TABLE
#
#    self_referencing_column_name  reference_generation  \
# 0                           NaN                   NaN
# 1                           NaN                   NaN
# 2                           NaN                   NaN
# 3                           NaN                   NaN
#
#    user_defined_type_catalog  user_defined_type_schema  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
#
#    user_defined_type_name is_insertable_into is_typed commit_action
# ...

# %%
conn.execute("SELECT * FROM NVDA_minute_30").df().tail(10)
# Out:
#      symbol                 timestamp    open    high     low   close  \
# 3989   NVDA 2024-01-11 16:30:00-06:00  546.82  548.22  546.35  546.97
# 3990   NVDA 2024-01-11 17:00:00-06:00  546.85  548.60  546.57  548.38
# 3991   NVDA 2024-01-11 17:30:00-06:00  548.20  548.40  547.00  547.01
# 3992   NVDA 2024-01-11 18:00:00-06:00  547.16  547.25  546.70  546.78
# 3993   NVDA 2024-01-11 18:30:00-06:00  546.75  546.98  544.65  544.71
# 3994   NVDA 2024-01-12 03:00:00-06:00  547.31  547.31  545.00  545.95
# 3995   NVDA 2024-01-12 03:30:00-06:00  545.69  545.84  545.00  545.02
# 3996   NVDA 2024-01-12 04:00:00-06:00  545.15  546.00  545.00  545.90
# 3997   NVDA 2024-01-12 04:30:00-06:00  545.75  545.75  544.52  545.02
# 3998   NVDA 2024-01-12 05:00:00-06:00  545.30  545.43  544.30  544.39
#
#        volume  trade_count        vwap
# 3989  28062.0        892.0  546.716655
# 3990  35761.0       1060.0  547.548302
# 3991  23938.0        764.0  547.776518
# ...

# %%
conn.close()

# %%
import pandas_market_calendars as mcal
import datetime

# %%
nyse_calendar = mcal.get_calendar('NYSE')

# %%
datetime.datetime(2023, 11, 24, 16, 13, 7, 38930) in nyse_calendar.holidays().holidays
# Out:
# False
